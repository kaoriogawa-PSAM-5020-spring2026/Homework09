# %% [markdown]
# # Homework09
#
# Exercises to practice dimensionality reduction with PCA
#
# ## Goals
#
# - Add unsupervised pre-processing to our ML flow: encode -> normalize -> pre-process -> train -> evaluate
# - Build an intuition for PCA and when/how to use it
# - Understand the benefits of dimensionality reduction

# %% [markdown]
# ### Setup
#
# Run the following 2 cells to import all necessary libraries and helpers for this homework.

# %%
# !wget -q https://github.com/PSAM-5020-2026S-A/5020-utils/raw/main/src/data_utils.py
# !wget -q https://github.com/PSAM-5020-2026S-A/5020-utils/raw/main/src/image_utils.py
# !wget -q https://github.com/PSAM-5020-2026S-A/Homework07/raw/main/Homework07_utils.pyc

# !wget -qO- https://github.com/PSAM-5020-2026S-A/5020-utils/releases/latest/download/0801-500.tar.gz | tar xz

# %%
from os import listdir, path
from PIL import Image as PImage

from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier

from image_utils import get_pixels, make_image

from Homework07_utils import CamUtils

# %% [markdown]
# ## PCA and Classification
#
# Let's practice doing some more image classification with `PCA` and analyzing the results.
#
# The dataset is the same one we used in `Homework07`. It has images from $25$ different security cameras, and our task is to separate them by camera. Some of the cameras move, some of them don't, and there are more than $1000$ images, so there's no way we want to do this by hand.
#
# Let's start by loading the training images into a list of pixels, like we did with the `faces` dataset in class.
#
# ### Loading Data
#
# If we look at the images in `./data/image/0801-500/train/`, we'll notice that they are named and organized in a slightly different way. They're all in the same directory and the first part of their filename specifies which camera they came from. Even though those `ids` are numbers, they're not sequential, so we'll use some helper functions to extract a unique `label` from their filenames.
#
# This is exactly what the `OrdinalEncoder` class does, but since we only have to encode this one column, we'll do it by hand while we read the files in.

# %%
# this creates a list of all the files in a given directory, that end in .jpg
train_files = [f for f in listdir("./data/image/0801-500/train") if f.endswith(".jpg")]

# %%
# TODO: check and see what is inside the list here
train_files
# Out:
# ['13-04.jpg',
#  '02-24.jpg',
#  '24-10.jpg',
#  '06-37.jpg',
#  '18-57.jpg',
#  '02-30.jpg',
#  '23-07.jpg',
#  '07-85.jpg',
#  '27-08.jpg',
#  '21-35.jpg',
#  '28-78.jpg',
#  '10-61.jpg',
#  '07-01.jpg',
#  '10-43.jpg',
#  '25-23.jpg',
#  '24-24.jpg',
#  '24-01.jpg',
#  '10-50.jpg',
#  '05-02.jpg',
#  '18-55.jpg',
#  '15-38.jpg',
#  '06-63.jpg',
#  '10-70.jpg',
#  '26-74.jpg',
#  '26-04.jpg',
#  '22-06.jpg',
#  '08-50.jpg',
#  '24-44.jpg',
#  '27-20.jpg',
#  '21-21.jpg',
#  '03-20.jpg',
#  '24-58.jpg',
#  '13-10.jpg',
#  '01-40.jpg',
#  '21-08.jpg',
#  '21-17.jpg',
#  '22-42.jpg',
#  '11-45.jpg',
#  '17-29.jpg',
#  '15-49.jpg',
#  '31-19.jpg',
#  '06-30.jpg',
#  '15-18.jpg',
#  '27-50.jpg',
#  '10-90.jpg',
#  '25-83.jpg',
#  '19-64.jpg',
#  '15-48.jpg',
#  '26-61.jpg',
#  '09-65.jpg',
#  '27-02.jpg',
#  '22-38.jpg',
#  '07-31.jpg',
#  '06-32.jpg',
#  '08-52.jpg',
#  '31-21.jpg',
#  '06-15.jpg',
#  '08-48.jpg',
#  '26-62.jpg',
#  '11-74.jpg',
#  '10-48.jpg',
#  '26-50.jpg',
#  '21-15.jpg',
#  '05-21.jpg',
#  '21-60.jpg',
#  '08-53.jpg',
#  '31-13.jpg',
#  '02-31.jpg',
#  '23-41.jpg',
#  '07-12.jpg',
#  '17-81.jpg',
#  '24-50.jpg',
#  '12-32.jpg',
#  '22-00.jpg',
#  '09-04.jpg',
#  '22-58.jpg',
#  '08-19.jpg',
#  '28-62.jpg',
#  '09-30.jpg',
#  '18-31.jpg',
#  '26-29.jpg',
#  '28-06.jpg',
#  '03-36.jpg',
#  '02-40.jpg',
#  '13-56.jpg',
#  '25-38.jpg',
#  '13-09.jpg',
#  '23-73.jpg',
#  '31-05.jpg',
#  '19-48.jpg',
#  '26-35.jpg',
#  '19-20.jpg',
#  '12-16.jpg',
#  '26-60.jpg',
#  '09-75.jpg',
#  '12-00.jpg',
#  '27-45.jpg',
#  '11-60.jpg',
#  '18-03.jpg',
#  '22-53.jpg',
#  '02-36.jpg',
#  '01-19.jpg',
#  '01-39.jpg',
#  '17-90.jpg',
#  '22-36.jpg',
#  '12-19.jpg',
#  '06-36.jpg',
#  '27-15.jpg',
#  '17-51.jpg',
#  '18-29.jpg',
#  '15-30.jpg',
#  '15-10.jpg',
#  '21-52.jpg',
#  '27-12.jpg',
#  '13-26.jpg',
#  '09-06.jpg',
#  '10-15.jpg',
#  '12-40.jpg',
#  '06-53.jpg',
#  '22-14.jpg',
#  '13-21.jpg',
#  '05-42.jpg',
#  '13-03.jpg',
#  '28-74.jpg',
#  '12-06.jpg',
#  '17-57.jpg',
#  '11-67.jpg',
#  '12-30.jpg',
#  '02-48.jpg',
#  '21-28.jpg',
#  '25-81.jpg',
#  '02-06.jpg',
#  '23-60.jpg',
#  '18-34.jpg',
#  '19-37.jpg',
#  '03-35.jpg',
#  '23-28.jpg',
#  '09-86.jpg',
#  '10-26.jpg',
#  '06-75.jpg',
#  '09-62.jpg',
#  '18-20.jpg',
#  '23-46.jpg',
#  '17-85.jpg',
#  '25-69.jpg',
#  '08-21.jpg',
#  '11-27.jpg',
#  '19-60.jpg',
#  '01-17.jpg',
#  '17-40.jpg',
#  '07-09.jpg',
#  '11-48.jpg',
#  '01-07.jpg',
#  '09-48.jpg',
#  '26-16.jpg',
#  '12-21.jpg',
#  '03-23.jpg',
#  '01-33.jpg',
#  '21-51.jpg',
#  '10-49.jpg',
#  '24-52.jpg',
#  '25-65.jpg',
#  '31-11.jpg',
#  '23-51.jpg',
#  '06-47.jpg',
#  '09-38.jpg',
#  '26-22.jpg',
#  '28-17.jpg',
#  '05-49.jpg',
#  '23-63.jpg',
#  '27-09.jpg',
#  '12-54.jpg',
#  '19-30.jpg',
#  '24-09.jpg',
#  '25-71.jpg',
#  '25-42.jpg',
#  '19-62.jpg',
#  '03-05.jpg',
#  '19-74.jpg',
#  '28-77.jpg',
#  '01-32.jpg',
#  '31-08.jpg',
#  '28-69.jpg',
#  '02-21.jpg',
#  '25-47.jpg',
#  '23-64.jpg',
#  '17-66.jpg',
#  '28-64.jpg',
#  '22-48.jpg',
#  '10-40.jpg',
#  '31-20.jpg',
#  '13-47.jpg',
#  '15-13.jpg',
#  '18-33.jpg',
#  '03-79.jpg',
#  '13-32.jpg',
#  '06-17.jpg',
#  '03-67.jpg',
#  '01-38.jpg',
#  '24-22.jpg',
#  '21-38.jpg',
#  '27-05.jpg',
#  '27-47.jpg',
#  '05-22.jpg',
#  '08-00.jpg',
#  '01-46.jpg',
#  '23-48.jpg',
#  '11-25.jpg',
#  '02-47.jpg',
#  '11-04.jpg',
#  '08-27.jpg',
#  '28-27.jpg',
#  '28-67.jpg',
#  '07-15.jpg',
#  '17-54.jpg',
#  '05-29.jpg',
#  '31-15.jpg',
#  '07-11.jpg',
#  '05-30.jpg',
#  '07-75.jpg',
#  '02-14.jpg',
#  '17-10.jpg',
#  '01-30.jpg',
#  '07-48.jpg',
#  '24-33.jpg',
#  '08-22.jpg',
#  '03-13.jpg',
#  '15-22.jpg',
#  '07-42.jpg',
#  '22-43.jpg',
#  '05-25.jpg',
#  '15-42.jpg',
#  '03-69.jpg',
#  '18-21.jpg',
#  '09-41.jpg',
#  '11-94.jpg',
#  '18-10.jpg',
#  '13-52.jpg',
#  '25-14.jpg',
#  '19-84.jpg',
#  '12-44.jpg',
#  '15-07.jpg',
#  '05-15.jpg',
#  '31-02.jpg',
#  '05-40.jpg',
#  '03-78.jpg',
#  '31-06.jpg',
#  '08-35.jpg',
#  '11-87.jpg',
#  '19-17.jpg']

# %% [markdown]
# Now we'll read the image pixels and extract their labels. `CamUtils.get_label()` is the helper function we'll use to "encode" and return a label id based on the filename.

# %%
pixel_data = []
label_data = []

for fname in train_files:
  label = CamUtils.get_label(fname)
  img = PImage.open(path.join("./data/image/0801-500/train", fname))
  pixel_data.append(get_pixels(img))
  label_data.append(label)

# %%
# TODO: check if labels got extracted correctly by looking at 
#       the first few items of the label list and the filename list
list(zip(train_files[:5], label_data[:5]))
# Out:
# [('13-04.jpg', 11),
#  ('02-24.jpg', 1),
#  ('24-10.jpg', 19),
#  ('06-37.jpg', 4),
#  ('18-57.jpg', 14)]

# %% [markdown]
# Like in `Homework07`, the labels and the filenames won't match exactly since labels start at $0$ and the filenames start at $01$ and skip some numbers.
#
# We can open some images from pixels, just to make sure we loaded them correctly:

# %%
display(make_image(pixel_data[0]))
display(make_image(pixel_data[10]))
# Out:
# <PIL.Image.Image image mode=L size=256x256>
# <PIL.Image.Image image mode=L size=256x256>

# %% [markdown]
# ### PCA
#
# Create a `DataFrame` called `cam_pca_df` by running `PCA` on the list of pixel data, just like we did in class, and then append a `label` column to it, just like we did in Homework07 with: `train_df["label"] = label_data`.
#
# You can change how many components to extract from the images later, but for this first run just use $10$ components so we can compare classification with $10$ `PCA` components to the classification with $10$ random features from `Homework07`.  Make sure to confirm how much of the `variance` is preserved by this transformation.

# %%
# TODO: run PCA, get DataFrame
cam_pca = PCA(n_components=8).set_output(transform="pandas")
cam_pca_df = cam_pca.fit_transform(pixel_data)

# TODO: add "label" column
cam_pca_df ["label"] =label_data

# TODO: print variance
print(sum(cam_pca.explained_variance_ratio_))

# TODO: take a look at the first 5 rows
cam_pca_df[:5]
# Out:
# 0.7443755033655227
#           pca0          pca1          pca2         pca3         pca4  \
# 0 -6439.367164 -10685.487154   -393.245865   699.026241  1202.629149
# 1 -5615.496419  -2789.052923   9526.371322   107.638408 -4238.415650
# 2 -8648.767151  -5391.152216   5267.286138 -1364.622311 -3260.493402
# 3  2017.741255  10999.238501   -921.293872 -7848.899561 -3105.917280
# 4  6193.021328   3488.275302 -13535.361724 -2919.270341 -3227.338613
#
#           pca5         pca6         pca7  label
# 0 -4966.245662  5179.931132   710.128378     11
# 1  1035.389520  1214.795403 -1800.281016      1
# 2 -1395.598723  -476.832207 -3354.118585     19
# 3  3922.558875  7171.811027 -3126.095587      4
# 4  2295.212407 -1845.716691 -1871.198530     14

# %% [markdown]
# ### Interpretation
#
# <span style="color:hotpink">
# How many components did you keep ?<br>
# Did you try different numbers ?<br>
# What percent of variance is kept by this transformation?
# </span>

# %% [markdown]
# <span style="color:hotpink;">EDIT THIS CELL WITH ANSWER</span> <br>
# I kept 10 components, and tried 11, 5,1, 20. <br>
# The percent variance was,0.74, 0.77, 0.79, 0.80, 0.64, 0.24, 0.88 for the number of components, 8, 9, 10 ,11, 5, 1, 20
# Since the vanriance only increased 0.01 from 10 to 11, adding 11th component would have a very limited influence even if we want to reach the sum of variance, say, 80%.

# %% [markdown]
# ### Reconstruct
#
# Before we go run our classification, let's take a look at some reconstructed images, just to make sure they make sense.
#
# Take a look at reconstructed versions of images $0$, $10$, and whichever other images you might have opened above.
#
# We did this in class. It involves a `inverse_transform()` function.

# %%
# TODO: reconstruct image at index 0
cam_pxs_0 = cam_pca.inverse_transform(cam_pca_df.drop(columns="label").iloc[[0]])
display(make_image(pixel_data[0]))
display(make_image(cam_pxs_0))

# TODO: reconstruct image at index 10
cam_pxs_10 = cam_pca.inverse_transform(cam_pca_df.drop(columns="label").iloc[[10]])
display(make_image(pixel_data[10]))
display(make_image(cam_pxs_10))
# Out:
# <PIL.Image.Image image mode=L size=256x256>
# <PIL.Image.Image image mode=L size=256x256>
# <PIL.Image.Image image mode=L size=256x256>
# <PIL.Image.Image image mode=L size=256x256>

# %% [markdown]
# The reconstructed images should look blurrier and noisier than the original ones, but they should still look something like the original ones.
#
# ### Classify !
#
# Train a `RandomForestClassifier` on the `PCA` data.
#
# Remember to separate the output feature (`label`) from the input features (`PC0`, `PC1`, etc).

# %%
cam_pca_analysis_df = cam_pca_df.drop(columns="label")

# TODO: create a classifier
mcls = RandomForestClassifier()

# TODO: split input and output features
in_df = cam_pca_analysis_df

# TODO: fit the model
mcls.fit(in_df, cam_pca_df["label"])

# TODO: run predictions
train_predictions = mcls.predict(in_df)

# %% [markdown]
# ### Measure Error
#
# For the train set we could use the generic `classification_error()` function that we've used before because we have the true labels for each file, but for measuring accuracy for our `test` set classification, which has secret labels, we have to use a more specific function from the `CamUtils` class.
#
# The function is called `classification_accuracy()` and it takes $2$ parameters, a list of filenames and the predicted labels associated with those filenames.
#
# The result is an accuracy score ratio, between $0.0$ and $1.0$.
#
# We can run this function on the `train` set as well:

# %%
# train_files is the list of files we got way up above
CamUtils.classification_accuracy(train_files, train_predictions)
# Out:
# 1.0

# %% [markdown]
# ### Interpretation
#
# <span style="color:hotpink">
# What does this mean?<br>
# Should we expect the same result from the test dataset?<br>
# Why, or why not?
# </span>

# %% [markdown]
# <span style="color:hotpink;">EDIT THIS CELL WITH ANSWER</span> <br>
# An accuracy of 1.0 means the model classified all training iamges correctly. However, this doesn't mean it will perform euqually well on the test dataset, because the model was evaluated on the same data it was trained on. So this score may reflect overfitting, or simply memorization of the training dataset. It's possible that the test accuracy is lower since the model hasn't seen any data in the test dataset.

# %% [markdown]
# ### Run on Test set
#
# Now we'll open the image files inside the `./data/image/0801-500/test/` directory, using almost the exact same steps as we did above to create a `DataFrame` with the exception that we don't have labels for these images.

# %%
# TODO: create a list of files in the test/ directory
test_files = [f for f in listdir("./data/image/0801-500/test") if f.endswith(".jpg")]


# TODO: check its length and content
print(len(test_files))
test_files
# Out:
# 1573
# ['7176838.jpg',
#  '5838086.jpg',
#  '12423813.jpg',
#  '8717209.jpg',
#  '6870122.jpg',
#  '5661831.jpg',
#  '8699096.jpg',
#  '15934002.jpg',
#  '7875957.jpg',
#  '10816486.jpg',
#  '14440202.jpg',
#  '15227757.jpg',
#  '5904696.jpg',
#  '15329192.jpg',
#  '15156201.jpg',
#  '15452765.jpg',
#  '16296437.jpg',
#  '14959463.jpg',
#  '11596954.jpg',
#  '7907358.jpg',
#  '14644826.jpg',
#  '8590343.jpg',
#  '8183339.jpg',
#  '14824123.jpg',
#  '15300989.jpg',
#  '8831032.jpg',
#  '13739887.jpg',
#  '14206185.jpg',
#  '12692500.jpg',
#  '7275429.jpg',
#  '14514271.jpg',
#  '10248414.jpg',
#  '11508132.jpg',
#  '8651963.jpg',
#  '8046222.jpg',
#  '8543611.jpg',
#  '6898947.jpg',
#  '7636764.jpg',
#  '8224906.jpg',
#  '15863781.jpg',
#  '9920425.jpg',
#  '10819242.jpg',
#  '16286384.jpg',
#  '15413772.jpg',
#  '11229651.jpg',
#  '8317552.jpg',
#  '8243804.jpg',
#  '7947689.jpg',
#  '10473474.jpg',
#  '12522500.jpg',
#  '15814524.jpg',
#  '16200707.jpg',
#  '5697447.jpg',
#  '9733942.jpg',
#  '10386127.jpg',
#  '15012689.jpg',
#  '8049378.jpg',
#  '7752588.jpg',
#  '14548198.jpg',
#  '16270909.jpg',
#  '12118799.jpg',
#  '15878814.jpg',
#  '10448922.jpg',
#  '5797617.jpg',
#  '14716551.jpg',
#  '14478345.jpg',
#  '13464650.jpg',
#  '10669441.jpg',
#  '12702500.jpg',
#  '6386475.jpg',
#  '8804586.jpg',
#  '5671005.jpg',
#  '10712100.jpg',
#  '13294183.jpg',
#  '11691492.jpg',
#  '16096608.jpg',
#  '13520051.jpg',
#  '10737300.jpg',
#  '13382431.jpg',
#  '6546256.jpg',
#  '10354550.jpg',
#  '8569853.jpg',
#  '8262608.jpg',
#  '9505313.jpg',
#  '15566277.jpg',
#  '11150387.jpg',
#  '12576674.jpg',
#  '6168839.jpg',
#  '10830297.jpg',
#  '8355052.jpg',
#  '12710918.jpg',
#  '8487403.jpg',
#  '16583627.jpg',
#  '14191233.jpg',
#  '15826192.jpg',
#  '8094544.jpg',
#  '10653850.jpg',
#  '13484601.jpg',
#  '5982312.jpg',
#  '14073927.jpg',
#  '5396560.jpg',
#  '7995815.jpg',
#  '5641706.jpg',
#  '5946562.jpg',
#  '6062009.jpg',
#  '10682680.jpg',
#  '14769874.jpg',
#  '10481650.jpg',
#  '15541284.jpg',
#  '12768655.jpg',
#  '7982251.jpg',
#  '13527647.jpg',
#  '10793987.jpg',
#  '13495811.jpg',
#  '5373680.jpg',
#  '13835371.jpg',
#  '12725834.jpg',
#  '7576632.jpg',
#  '7812504.jpg',
#  '10513078.jpg',
#  '12190821.jpg',
#  '12597500.jpg',
#  '9362651.jpg',
#  '7709688.jpg',
#  '8949234.jpg',
#  '10729278.jpg',
#  '8363359.jpg',
#  '8742594.jpg',
#  '10810994.jpg',
#  '15413431.jpg',
#  '8338723.jpg',
#  '8327248.jpg',
#  '8220592.jpg',
#  '7887991.jpg',
#  '16558099.jpg',
#  '13698455.jpg',
#  '14929872.jpg',
#  '7977395.jpg',
#  '7848455.jpg',
#  '8068747.jpg',
#  '9876440.jpg',
#  '13565350.jpg',
#  '8654109.jpg',
#  '15694854.jpg',
#  '13766417.jpg',
#  '5799889.jpg',
#  '10619080.jpg',
#  '9536495.jpg',
#  '7249347.jpg',
#  '11088893.jpg',
#  '12278193.jpg',
#  '11149475.jpg',
#  '7891133.jpg',
#  '11131633.jpg',
#  '5592165.jpg',
#  '13703150.jpg',
#  '14170259.jpg',
#  '15901430.jpg',
#  '15723444.jpg',
#  '15820570.jpg',
#  '15584210.jpg',
#  '12229653.jpg',
#  '9432555.jpg',
#  '8113046.jpg',
#  '12482206.jpg',
#  '6584176.jpg',
#  '5590599.jpg',
#  '5661614.jpg',
#  '11819482.jpg',
#  '11305225.jpg',
#  '8385424.jpg',
#  '8243216.jpg',
#  '14953296.jpg',
#  '12457346.jpg',
#  '5253040.jpg',
#  '15505176.jpg',
#  '12452374.jpg',
#  '8170574.jpg',
#  '6059928.jpg',
#  '10571822.jpg',
#  '15920752.jpg',
#  '11942161.jpg',
#  '12673085.jpg',
#  '10883502.jpg',
#  '10423081.jpg',
#  '10920262.jpg',
#  '14900323.jpg',
#  '14877168.jpg',
#  '16180399.jpg',
#  '14428834.jpg',
#  '14648445.jpg',
#  '8131434.jpg',
#  '13479893.jpg',
#  '5907048.jpg',
#  '10845533.jpg',
#  '6769059.jpg',
#  '8794254.jpg',
#  '6153324.jpg',
#  '8172462.jpg',
#  '7364358.jpg',
#  '11041334.jpg',
#  '8206949.jpg',
#  '8513569.jpg',
#  '9821560.jpg',
#  '12923369.jpg',
#  '12156843.jpg',
#  '8349872.jpg',
#  '6081096.jpg',
#  '8117357.jpg',
#  '6100862.jpg',
#  '10995371.jpg',
#  '9329729.jpg',
#  '10644520.jpg',
#  '6996363.jpg',
#  '5626222.jpg',
#  '12190409.jpg',
#  '8303369.jpg',
#  '14672208.jpg',
#  '10272550.jpg',
#  '14663793.jpg',
#  '11067714.jpg',
#  '15794672.jpg',
#  '8523583.jpg',
#  '16153632.jpg',
#  '15251952.jpg',
#  '13559949.jpg',
#  '6131508.jpg',
#  '9326071.jpg',
#  '13775229.jpg',
#  '11041879.jpg',
#  '10850700.jpg',
#  '16197984.jpg',
#  '11549388.jpg',
#  '8490351.jpg',
#  '7880604.jpg',
#  '7550982.jpg',
#  '7123562.jpg',
#  '10428350.jpg',
#  '7908036.jpg',
#  '16162670.jpg',
#  '6869698.jpg',
#  '12593703.jpg',
#  '7278327.jpg',
#  '5970552.jpg',
#  '13146751.jpg',
#  '7920228.jpg',
#  '8068314.jpg',
#  '7907217.jpg',
#  '5311280.jpg',
#  '9293149.jpg',
#  '7712712.jpg',
#  '10579109.jpg',
#  '11659404.jpg',
#  '7904202.jpg',
#  '10865542.jpg',
#  '10848967.jpg',
#  '7388451.jpg',
#  '10579866.jpg',
#  '8322653.jpg',
#  '5728611.jpg',
#  '5655153.jpg',
#  '8483667.jpg',
#  '12972500.jpg',
#  '8204432.jpg',
#  '8695624.jpg',
#  '5755323.jpg',
#  '11595228.jpg',
#  '8630399.jpg',
#  '14988432.jpg',
#  '14887241.jpg',
#  '11590025.jpg',
#  '14512365.jpg',
#  '12416065.jpg',
#  '16424077.jpg',
#  '10623320.jpg',
#  '15785592.jpg',
#  '11028362.jpg',
#  '11389775.jpg',
#  '12681086.jpg',
#  '10616063.jpg',
#  '10771720.jpg',
#  '8892343.jpg',
#  '14342265.jpg',
#  '15629464.jpg',
#  '15940195.jpg',
#  '11318575.jpg',
#  '15877032.jpg',
#  '5961029.jpg',
#  '6501225.jpg',
#  '14035811.jpg',
#  '7458003.jpg',
#  '5542166.jpg',
#  '5886554.jpg',
#  '9283265.jpg',
#  '9280095.jpg',
#  '9254685.jpg',
#  '5892936.jpg',
#  '11842764.jpg',
#  '10895007.jpg',
#  '11444787.jpg',
#  '12683915.jpg',
#  '5487045.jpg',
#  '15213396.jpg',
#  '5323760.jpg',
#  '10670100.jpg',
#  '12004922.jpg',
#  '8768536.jpg',
#  '10896354.jpg',
#  '8094777.jpg',
#  '12333629.jpg',
#  '9444745.jpg',
#  '15449574.jpg',
#  '8502292.jpg',
#  '9252911.jpg',
#  '5377840.jpg',
#  '15161823.jpg',
#  '14275366.jpg',
#  '14812752.jpg',
#  '10457050.jpg',
#  '11426859.jpg',
#  '7573608.jpg',
#  '7792212.jpg',
#  '15229973.jpg',
#  '12995005.jpg',
#  '5995537.jpg',
#  '8876168.jpg',
#  '14495355.jpg',
#  '10509307.jpg',
#  '10892027.jpg',
#  '11252061.jpg',
#  '13819477.jpg',
#  '5784261.jpg',
#  '13516893.jpg',
#  '10308113.jpg',
#  '10395726.jpg',
#  '6724762.jpg',
#  '6844827.jpg',
#  '15390472.jpg',
#  '6019944.jpg',
#  '7649208.jpg',
#  '8263436.jpg',
#  '7965115.jpg',
#  '8526979.jpg',
#  '7739928.jpg',
#  '8084282.jpg',
#  '10228525.jpg',
#  '11054266.jpg',
#  '7793195.jpg',
#  '7791336.jpg',
#  '8923249.jpg',
#  '12949574.jpg',
#  '14766743.jpg',
#  '9351677.jpg',
#  '8672567.jpg',
#  '10788683.jpg',
#  '11024038.jpg',
#  '12299185.jpg',
#  '9684386.jpg',
#  '9165119.jpg',
#  '10632487.jpg',
#  '5727974.jpg',
#  '15708610.jpg',
#  '15977215.jpg',
#  '15087984.jpg',
#  '10839560.jpg',
#  '13549450.jpg',
#  '7160014.jpg',
#  '12621422.jpg',
#  '8943853.jpg',
#  '14565913.jpg',
#  '15136883.jpg',
#  '5484855.jpg',
#  '7117954.jpg',
#  '8263258.jpg',
#  '7417431.jpg',
#  '7362369.jpg',
#  '8143024.jpg',
#  '15730415.jpg',
#  '5775357.jpg',
#  '13864183.jpg',
#  '14935728.jpg',
#  '8408251.jpg',
#  '10656623.jpg',
#  '14722413.jpg',
#  '11176175.jpg',
#  '15676458.jpg',
#  '13480550.jpg',
#  '14405249.jpg',
#  '5878157.jpg',
#  '7721784.jpg',
#  '8151919.jpg',
#  '8976856.jpg',
#  '14231881.jpg',
#  '13522707.jpg',
#  '5359120.jpg',
#  '13967899.jpg',
#  '16117741.jpg',
#  '7258041.jpg',
#  '5945683.jpg',
#  '14431431.jpg',
#  '10329950.jpg',
#  '10233704.jpg',
#  '12046646.jpg',
#  '8174809.jpg',
#  '15324661.jpg',
#  '13245893.jpg',
#  '10804413.jpg',
#  '15458935.jpg',
#  '9116745.jpg',
#  '9080445.jpg',
#  '15736585.jpg',
#  '8085937.jpg',
#  '7892796.jpg',
#  '13818307.jpg',
#  '9424837.jpg',
#  '5317520.jpg',
#  '16369056.jpg',
#  '8724077.jpg',
#  '8148202.jpg',
#  '15070416.jpg',
#  '7935121.jpg',
#  '9550966.jpg',
#  '5900402.jpg',
#  '6796119.jpg',
#  '14240205.jpg',
#  '14682465.jpg',
#  '11131675.jpg',
#  '16213471.jpg',
#  '7818552.jpg',
#  '5959927.jpg',
#  '14718718.jpg',
#  '11238475.jpg',
#  '12569433.jpg',
#  '13936689.jpg',
#  '15945968.jpg',
#  '15868512.jpg',
#  '8490203.jpg',
#  '13599941.jpg',
#  '14263851.jpg',
#  '14456891.jpg',
#  '14710815.jpg',
#  '7454754.jpg',
#  '5747882.jpg',
#  '7923138.jpg',
#  '15930604.jpg',
#  '10729877.jpg',
#  '16502112.jpg',
#  '8013671.jpg',
#  '15486366.jpg',
#  '7518861.jpg',
#  '15510894.jpg',
#  '15674885.jpg',
#  '8625498.jpg',
#  '11615498.jpg',
#  '15486888.jpg',
#  '8871739.jpg',
#  '9413863.jpg',
#  '13414447.jpg',
#  '13570821.jpg',
#  '15359124.jpg',
#  '13683087.jpg',
#  '8259841.jpg',
#  '10719593.jpg',
#  '15653049.jpg',
#  '11523275.jpg',
#  '16242256.jpg',
#  '12201785.jpg',
#  '7691885.jpg',
#  '8162416.jpg',
#  '7033082.jpg',
#  '9021992.jpg',
#  '6111672.jpg',
#  '6137977.jpg',
#  '11399967.jpg',
#  '7573923.jpg',
#  '10808727.jpg',
#  '10616950.jpg',
#  '8345236.jpg',
#  '8084848.jpg',
#  '13530703.jpg',
#  '16026912.jpg',
#  '9323635.jpg',
#  '6485925.jpg',
#  '8217628.jpg',
#  '8589641.jpg',
#  '12161697.jpg',
#  '13564789.jpg',
#  '12321879.jpg',
#  '15489785.jpg',
#  '8282927.jpg',
#  '9896725.jpg',
#  '8624491.jpg',
#  '13580707.jpg',
#  '7916269.jpg',
#  '13868503.jpg',
#  '8164487.jpg',
#  '15093859.jpg',
#  '5692582.jpg',
#  '13672971.jpg',
#  '15832496.jpg',
#  '7244134.jpg',
#  '5570265.jpg',
#  '9191515.jpg',
#  '11961257.jpg',
#  '13256329.jpg',
#  '12613119.jpg',
#  '9892775.jpg',
#  '7782264.jpg',
#  '5417360.jpg',
#  '9187067.jpg',
#  '14548737.jpg',
#  '14821631.jpg',
#  '7466697.jpg',
#  '11002857.jpg',
#  '11989901.jpg',
#  '5995559.jpg',
#  '11545525.jpg',
#  '10886522.jpg',
#  '15912864.jpg',
#  '15101399.jpg',
#  '10571682.jpg',
#  '8329099.jpg',
#  '6882711.jpg',
#  '15395448.jpg',
#  '14858551.jpg',
#  '11021207.jpg',
#  '13923657.jpg',
#  '14880687.jpg',
#  '10869123.jpg',
#  '15816072.jpg',
#  '13708051.jpg',
#  '10312219.jpg',
#  '9167565.jpg',
#  '8052322.jpg',
#  '15216816.jpg',
#  '10849549.jpg',
#  '5848231.jpg',
#  '10954040.jpg',
#  '5843627.jpg',
#  '14910193.jpg',
#  '8371973.jpg',
#  '10098175.jpg',
#  '13201901.jpg',
#  '8383387.jpg',
#  '12995581.jpg',
#  '11851934.jpg',
#  '5884246.jpg',
#  '6626175.jpg',
#  '15232407.jpg',
#  '15034679.jpg',
#  '12171313.jpg',
#  '14651983.jpg',
#  '10855402.jpg',
#  '15586568.jpg',
#  '14183505.jpg',
#  '14686411.jpg',
#  '7770876.jpg',
#  '5858858.jpg',
#  '9258315.jpg',
#  '10506300.jpg',
#  '7874508.jpg',
#  '8216591.jpg',
#  '5675187.jpg',
#  '15874848.jpg',
#  '16505473.jpg',
#  '9521815.jpg',
#  '12917500.jpg',
#  '15144477.jpg',
#  '14817527.jpg',
#  '14909997.jpg',
#  '11911524.jpg',
#  '8194724.jpg',
#  '8323982.jpg',
#  '12954317.jpg',
#  '11296325.jpg',
#  '5650701.jpg',
#  '5563695.jpg',
#  '15857890.jpg',
#  '8000997.jpg',
#  '7975967.jpg',
#  '5780386.jpg',
#  '11708218.jpg',
#  '9352695.jpg',
#  '10461198.jpg',
#  '8180162.jpg',
#  '14297367.jpg',
#  '12258777.jpg',
#  '9341805.jpg',
#  '11024874.jpg',
#  '13324163.jpg',
#  '14835599.jpg',
#  '15384344.jpg',
#  '9246565.jpg',
#  '8820616.jpg',
#  '8780478.jpg',
#  '6817767.jpg',
#  '11145025.jpg',
#  '15247727.jpg',
#  '15578346.jpg',
#  '6424725.jpg',
#  '5639494.jpg',
#  '10964898.jpg',
#  '6511425.jpg',
#  '12632845.jpg',
#  '15310104.jpg',
#  '10924360.jpg',
#  '9378105.jpg',
#  '12654695.jpg',
#  '11465425.jpg',
#  '15147121.jpg',
#  '11171725.jpg',
#  '11630075.jpg',
#  '12552500.jpg',
#  '5939976.jpg',
#  '11646477.jpg',
#  '5893478.jpg',
#  '15623336.jpg',
#  '10513891.jpg',
#  '8628942.jpg',
#  '6440025.jpg',
#  '16305696.jpg',
#  '13257950.jpg',
#  '13613769.jpg',
#  '10734151.jpg',
#  '11870268.jpg',
#  '11114838.jpg',
#  '15658062.jpg',
#  '5998776.jpg',
#  '14951031.jpg',
#  '8026754.jpg',
#  '10972659.jpg',
#  '13944493.jpg',
#  '10177175.jpg',
#  '7376022.jpg',
#  '13400303.jpg',
#  '10046825.jpg',
#  '11011961.jpg',
#  '9091335.jpg',
#  '11718996.jpg',
#  '12899854.jpg',
#  '8058846.jpg',
#  '5555438.jpg',
#  '8600357.jpg',
#  '6090504.jpg',
#  '15882770.jpg',
#  '8159838.jpg',
#  '7679436.jpg',
#  '10811083.jpg',
#  '15193392.jpg',
#  '9958760.jpg',
#  '16178976.jpg',
#  '15267579.jpg',
#  '7970478.jpg',
#  '6389025.jpg',
#  '10870919.jpg',
#  '13394403.jpg',
#  '15755095.jpg',
#  '8309797.jpg',
#  '11645652.jpg',
#  '8369264.jpg',
#  '8723863.jpg',
#  '13439245.jpg',
#  '11131974.jpg',
#  '12476849.jpg',
#  '13454050.jpg',
#  '7565562.jpg',
#  '5598735.jpg',
#  '7753285.jpg',
#  '11977106.jpg',
#  '5595254.jpg',
#  '6990478.jpg',
#  '12386143.jpg',
#  '10493950.jpg',
#  '8779021.jpg',
#  '16487897.jpg',
#  '12437458.jpg',
#  '15920090.jpg',
#  '12343177.jpg',
#  '10744781.jpg',
#  '13601837.jpg',
#  '6052872.jpg',
#  '8304806.jpg',
#  '9418035.jpg',
#  '9950920.jpg',
#  '15845187.jpg',
#  '14701488.jpg',
#  '13272959.jpg',
#  '5517705.jpg',
#  '11208686.jpg',
#  '13446571.jpg',
#  '8194093.jpg',
#  '7486983.jpg',
#  '13512011.jpg',
#  '8039821.jpg',
#  '10768343.jpg',
#  '10852280.jpg',
#  '8747704.jpg',
#  '15843944.jpg',
#  '10309794.jpg',
#  '14865456.jpg',
#  '7937485.jpg',
#  '10749900.jpg',
#  '6109489.jpg',
#  '5817651.jpg',
#  '10530762.jpg',
#  '14241262.jpg',
#  '14945909.jpg',
#  '8350007.jpg',
#  '9268585.jpg',
#  '15485499.jpg',
#  '7306038.jpg',
#  '10704233.jpg',
#  '5539605.jpg',
#  '10618841.jpg',
#  '10697702.jpg',
#  '8374684.jpg',
#  '16080711.jpg',
#  '5657865.jpg',
#  '15582335.jpg',
#  '14634769.jpg',
#  '8210896.jpg',
#  '8322332.jpg',
#  '5284240.jpg',
#  '7869139.jpg',
#  '5305040.jpg',
#  '8276524.jpg',
#  '5573134.jpg',
#  '7303018.jpg',
#  '8309311.jpg',
#  '14114239.jpg',
#  '5794234.jpg',
#  '8473513.jpg',
#  '9558515.jpg',
#  '10452950.jpg',
#  '10548300.jpg',
#  '11041683.jpg',
#  '14100427.jpg',
#  '8023558.jpg',
#  '10659938.jpg',
#  '8865752.jpg',
#  '14669197.jpg',
#  '9393365.jpg',
#  '6116611.jpg',
#  '5962718.jpg',
#  '8312516.jpg',
#  '6909771.jpg',
#  '15111613.jpg',
#  '13772050.jpg',
#  '10518900.jpg',
#  '8380049.jpg',
#  '12540309.jpg',
#  '13533550.jpg',
#  '14461335.jpg',
#  '6762338.jpg',
#  '7697724.jpg',
#  '8119438.jpg',
#  '8041949.jpg',
#  '11067523.jpg',
#  '15615861.jpg',
#  '12795442.jpg',
#  '6972009.jpg',
#  '5980706.jpg',
#  '15960376.jpg',
#  '16324208.jpg',
#  '15899096.jpg',
#  '12782500.jpg',
#  '12532945.jpg',
#  '16081810.jpg',
#  '10985122.jpg',
#  '16135088.jpg',
#  '14506379.jpg',
#  '16621919.jpg',
#  '8621057.jpg',
#  '7655052.jpg',
#  '10272966.jpg',
#  '7857864.jpg',
#  '10930781.jpg',
#  '15024517.jpg',
#  '8049463.jpg',
#  '11179702.jpg',
#  '10911640.jpg',
#  '10714486.jpg',
#  '12231005.jpg',
#  '8693821.jpg',
#  '6874593.jpg',
#  '11930746.jpg',
#  '10821300.jpg',
#  '15633534.jpg',
#  '12610865.jpg',
#  '8851864.jpg',
#  '10959717.jpg',
#  '10623900.jpg',
#  '11986378.jpg',
#  '15666232.jpg',
#  '6054887.jpg',
#  '15770408.jpg',
#  '10293050.jpg',
#  '11218618.jpg',
#  '7260958.jpg',
#  '11534427.jpg',
#  '8292022.jpg',
#  '15615310.jpg',
#  '12204731.jpg',
#  '15017967.jpg',
#  '6901653.jpg',
#  '8004382.jpg',
#  '6722078.jpg',
#  '10848758.jpg',
#  '6076392.jpg',
#  '15314303.jpg',
#  '13963599.jpg',
#  '7594776.jpg',
#  '6038269.jpg',
#  '10999139.jpg',
#  '8136209.jpg',
#  '6333904.jpg',
#  '16232617.jpg',
#  '9450443.jpg',
#  '13803850.jpg',
#  '16012533.jpg',
#  '16097264.jpg',
#  '11067278.jpg',
#  '9222015.jpg',
#  '15249828.jpg',
#  '7446006.jpg',
#  '9214755.jpg',
#  '8716456.jpg',
#  '11638678.jpg',
#  '8520383.jpg',
#  '14514094.jpg',
#  '7402266.jpg',
#  '10074475.jpg',
#  '5630667.jpg',
#  '9457759.jpg',
#  '5577243.jpg',
#  '10033240.jpg',
#  '16115616.jpg',
#  '14969581.jpg',
#  '5352880.jpg',
#  '10651546.jpg',
#  '6963891.jpg',
#  '14320838.jpg',
#  '12433883.jpg',
#  '10859100.jpg',
#  '15289153.jpg',
#  '8071498.jpg',
#  '6641475.jpg',
#  '13428665.jpg',
#  '6603225.jpg',
#  '14299219.jpg',
#  '14029239.jpg',
#  '9195185.jpg',
#  '6853594.jpg',
#  '6963638.jpg',
#  '15053931.jpg',
#  '15052433.jpg',
#  '11956483.jpg',
#  '11256543.jpg',
#  '12435545.jpg',
#  '11705244.jpg',
#  '8556661.jpg',
#  '9455755.jpg',
#  '10682700.jpg',
#  '10034975.jpg',
#  '8052677.jpg',
#  '12527500.jpg',
#  '15103443.jpg',
#  '10933691.jpg',
#  '8489204.jpg',
#  '16298992.jpg',
#  '8097673.jpg',
#  '6777177.jpg',
#  '13310950.jpg',
#  '13406350.jpg',
#  '15304008.jpg',
#  '14464947.jpg',
#  '10951089.jpg',
#  '8360021.jpg',
#  '7951542.jpg',
#  '9490681.jpg',
#  '7547841.jpg',
#  '8814918.jpg',
#  '10264075.jpg',
#  '5585595.jpg',
#  '10826840.jpg',
#  '11115021.jpg',
#  '14754192.jpg',
#  '15347576.jpg',
#  '10484671.jpg',
#  '12844105.jpg',
#  '15298404.jpg',
#  '7931345.jpg',
#  '5761154.jpg',
#  '8011506.jpg',
#  '10040056.jpg',
#  '12723385.jpg',
#  '15788792.jpg',
#  '10633062.jpg',
#  '11171054.jpg',
#  '8749482.jpg',
#  '11015799.jpg',
#  '15353704.jpg',
#  '8272304.jpg',
#  '16315583.jpg',
#  '5719126.jpg',
#  '10212725.jpg',
#  '11588211.jpg',
#  '13995723.jpg',
#  '10350714.jpg',
#  '16464096.jpg',
#  '8686303.jpg',
#  '12556786.jpg',
#  '8421443.jpg',
#  '12075833.jpg',
#  '6133229.jpg',
#  '14783957.jpg',
#  '8214356.jpg',
#  '10236138.jpg',
#  '6593025.jpg',
#  '15087941.jpg',
#  '7983102.jpg',
#  '8188242.jpg',
#  '14804481.jpg',
#  '8847701.jpg',
#  '7938516.jpg',
#  '10870721.jpg',
#  '13355471.jpg',
#  '12331587.jpg',
#  '5949384.jpg',
#  '6990951.jpg',
#  '10694077.jpg',
#  '12219053.jpg',
#  '6861646.jpg',
#  '14707344.jpg',
#  '11349725.jpg',
#  '10443611.jpg',
#  '5988106.jpg',
#  '13532953.jpg',
#  '10209640.jpg',
#  '12386845.jpg',
#  '5690715.jpg',
#  '10732187.jpg',
#  '13832059.jpg',
#  '13742937.jpg',
#  '10600550.jpg',
#  '12526954.jpg',
#  '8453212.jpg',
#  '9385365.jpg',
#  '6076253.jpg',
#  '5662245.jpg',
#  '12380127.jpg',
#  '12855106.jpg',
#  '10370950.jpg',
#  '12646282.jpg',
#  '8904462.jpg',
#  '14910401.jpg',
#  '16001568.jpg',
#  '11127814.jpg',
#  '15305679.jpg',
#  '8430119.jpg',
#  '11209929.jpg',
#  '12394689.jpg',
#  '11196234.jpg',
#  '7857665.jpg',
#  '11865842.jpg',
#  '6934114.jpg',
#  '8430308.jpg',
#  '6899998.jpg',
#  '5938561.jpg',
#  '8200866.jpg',
#  '11363075.jpg',
#  '12491769.jpg',
#  '15434255.jpg',
#  '14970864.jpg',
#  '10496989.jpg',
#  '15733623.jpg',
#  '5735289.jpg',
#  '13759721.jpg',
#  '10204825.jpg',
#  '14577389.jpg',
#  '8697822.jpg',
#  '15733490.jpg',
#  '9916475.jpg',
#  '6401775.jpg',
#  '9145785.jpg',
#  '5530845.jpg',
#  '5221840.jpg',
#  '10648760.jpg',
#  '9269205.jpg',
#  '10436646.jpg',
#  '10518089.jpg',
#  '7844028.jpg',
#  '10543038.jpg',
#  '15897005.jpg',
#  '14234535.jpg',
#  '10913700.jpg',
#  '7830648.jpg',
#  '10725080.jpg',
#  '10834611.jpg',
#  '9503465.jpg',
#  ...]

# %% [markdown]
# We'll use a similar loop to extract the pixel information from these images, except we don't have `label` data, just pixels.

# %%
test_pixel_data = []

for fname in test_files:
  img = PImage.open(path.join("./data/image/0801-500/test", fname))
  test_pixel_data.append(get_pixels(img))

# %% [markdown]
# Now we can run `PCA` and the `RandomForestClassifier`.
#
# Since those are already trained, all we have to do is run their `transform()` function on the data.

# %%
# TODO: run PCA on test pixels, get DataFrame
#       this is the same PCA that was created above, not a new one
test_cam_pca_df = cam_pca.transform(test_pixel_data)
test_cam_pca_df
# Out:
#               pca0         pca1         pca2         pca3         pca4  \
# 0     12102.833585  -520.709141 -1912.158261  -897.593932  3353.594594
# 1      4987.367280  7142.303704 -7497.509912   822.819229  4251.753511
# 2     10701.551532  3115.438945 -2473.683401 -2911.769806  5464.939458
# 3      -668.825998  3111.231147  1798.349074  6116.567040  2507.632649
# 4      1534.585946  8074.313048 -4342.779038  -575.788990  3536.282923
# ...            ...          ...          ...          ...          ...
# 1568 -12026.677536  9607.401403 -3698.754168  1859.555785  2538.205950
# 1569   9954.789018  -424.963082  4564.620224  1742.439056  1661.265103
# 1570   1457.299794 -6594.749389 -3210.912955  8839.960988  1704.387764
# 1571  -9335.699952 -6183.123661 -1082.153672 -1637.028793  1219.180826
# 1572    191.750806 -3247.907854  -721.003763  5240.173325 -1892.819731
#
#              pca5         pca6         pca7
# 0    -2479.274398   502.561684   408.941560
# 1    -1238.863901  -516.439020   590.860601
# 2    -3760.789016  1887.218412   269.418405
# 3    -1057.071245 -1603.034906  -807.942066
# 4      263.553831 -1885.375805  3350.595247
# ...           ...          ...          ...
# 1568  -429.645284  -930.680674   304.267956
# 1569 -1122.852678 -2957.887551  1500.952658
# 1570  6247.811510  3691.219667 -1591.566015
# 1571 -2420.221047   -28.332979 -1219.854736
# 1572  -129.003331 -2950.312927 -3724.474945
#
# [1573 rows x 8 columns]

# %% [markdown]
# It's always a good idea to check the result of the `PCA` transformation by looking at the `DataFrame` and reconstructing some images.

# %%
# TODO: reconstruct one or two images
test_cam_pxs_0 = cam_pca.inverse_transform(test_cam_pca_df.iloc[[0]])
display(make_image(test_pixel_data[0]))
display(make_image(test_cam_pxs_0))


# TODO: take a look at the first 5 rows
test_cam_pca_df[:5]
# Out:
# <PIL.Image.Image image mode=L size=256x256>
# <PIL.Image.Image image mode=L size=256x256>
#            pca0         pca1         pca2         pca3         pca4  \
# 0  12102.833585  -520.709141 -1912.158261  -897.593932  3353.594594
# 1   4987.367280  7142.303704 -7497.509912   822.819229  4251.753511
# 2  10701.551532  3115.438945 -2473.683401 -2911.769806  5464.939458
# 3   -668.825998  3111.231147  1798.349074  6116.567040  2507.632649
# 4   1534.585946  8074.313048 -4342.779038  -575.788990  3536.282923
#
#           pca5         pca6         pca7
# 0 -2479.274398   502.561684   408.941560
# 1 -1238.863901  -516.439020   590.860601
# 2 -3760.789016  1887.218412   269.418405
# 3 -1057.071245 -1603.034906  -807.942066
# 4   263.553831 -1885.375805  3350.595247

# %% [markdown]
# ### Interpretation
#
# <span style="color:hotpink"><br>
# The reconstructed images from the `test` set will always be noisier than the `train` images.<br><br>
# Why?<br><br>
# </span>

# %% [markdown]
# <span style="color:hotpink;">EDIT THIS CELL WITH ANSWER</span> <br>
# Since the model is trained with trained data, the model can represent the feature of the trained data better than the test data, which the model hasn't seen befofe.

# %% [markdown]
# Run the classifier and get predicted labels. Then get its accuracy ratio is by running the `CamUtils.classification_accuracy()` function with the list of filenames and list of predictions.

# %%
# TODO: run classifier. This is the same classifier already fitted on the train data above
# TODO: split input and output features

# TODO: run predictions
test_predictions = mcls.predict(test_cam_pca_df)

# TODO: get accuracy
CamUtils.classification_accuracy(test_files, test_predictions)
# Out:
# 0.9065479974570884

# %% [markdown]
# ### Interpretation
#
# <span style="color:hotpink">
# What's the accuracy ? How could we improve that if we wanted ?<br>
# How does this compare to the classification model from <code>Homework07</code>? They can both be tuned to perform well, but how many features did we need last time in order to get an accuracy comparable to this?
# </span>

# %% [markdown]
# <span style="color:hotpink;">EDIT THIS CELL WITH ANSWER</span> <br>
# We could improve the accuracy by increasing the number of component if wanted. <br>
# This model is more accurate compare to the classification model from Homework 07 with less number of features needed.
